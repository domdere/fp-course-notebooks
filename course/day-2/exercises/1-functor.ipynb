-- %% [markdown]
-- # Functor Exercises
--
-- ## IGNORE ME (config and dependencies)

-- %%
:set -XNoImplicitPrelude
:set -XTypeSynonymInstances
:set -XInstanceSigs
:load ../../original-source/Course/Core.hs
:load ../../original-source/Course/ExactlyOne.hs
:load ../../original-source/Course/Optional.hs
:load ../../original-source/Course/List.hs
import qualified Prelude as P (fmap)

-- %% [markdown]
-- ## The Functor Typeclass
--
-- ### The Definition

-- %%
class Functor f where
  -- Pronounced, eff-map.
  fmap :: (a -> b) -> f a -> f b
  -- For completeness, include the operator
  -- version of fmap
  (<$>) :: (a -> b) -> f a -> f b
  (<$>) = fmap

infixr 4 <$>

-- %% [markdown]
-- As a concept, this is hopefully not new to a lot of people, containers and etc... in Java, `C#` and
-- etc... have had `.map` methods on them for a while now, and `C++` has had a [`transform` "algorithm"](http://en.cppreference.com/w/cpp/algorithm/transform) in its standard library.
--
-- After this however, the concepts will begin to diverge from other common approaches.
--
-- The key thing to notice here is the laws described below. We apply laws to decide if any new
-- data type is a valid candidate for the `Functor` typeclass, so we do not have to prescribe "best practices"
-- to consumers of the data type, forcing them to consciously avoid the exceptions to the rule.
--
--
-- ### Question
--
-- As you can see above the type definition for `fmap` looked like this:
--
-- ``` haskell
-- fmap :: (a -> b) -> f a -> f b
-- ```
--
-- Once you feel like you understand what this type is saying, try this:

-- %%
:t fmap
-- Out:
-- fmap :: forall (f :: * -> *) a b. Functor f => (a -> b) -> f a -> f b

-- %% [markdown]
-- Discuss amongst the group (if you have one) what the following means:
--
-- 1. `Functor f =>`. This is called a (class) constraint
-- 2. (Optional/Advanced) `forall (f :: * -> *) a b.`

-- %% [markdown]
-- ### The Laws
-- All instances of the `Functor` type-class must satisfy two laws.
--
-- These laws are **NOT** checked by the compiler.
--
-- #### The law of identity
--
-- > The `fmap` function *turns* the identity function `id :: a -> a` into the identity function `id :: f a -> f a`
--
-- ```
-- ∀x. (fmap id x) ≅ x
-- ```
--
-- #### The law of composition
--
-- > You can compose the functions first and then `fmap`, or you can `fmap` the functions first and then compose the
-- > result, its all the same
--
-- ```
-- ∀f g x.(fmap (f . g) x) ≅ (fmap f . fmap g) x
-- ```

-- %% [markdown]
-- ### Instance/Example
--
-- #### `ExactlyOne`
--
-- Maps a function on the `ExactlyOne` Functor:

-- %%
instance Functor ExactlyOne where
  fmap :: (a -> b) -> ExactlyOne a -> ExactlyOne b
  fmap f (ExactlyOne x) = ExactlyOne (f x)
-- Out:
-- <interactive>:2:11: error:
--     * Illegal type signature in instance declaration: fmap :: (a -> b) -> ExactlyOne a -> ExactlyOne b
--       (Use InstanceSigs to allow this)
--     * In the instance declaration for `Functor ExactlyOne'

-- %%
-- you can play around with some examples here
fmap (+1) (ExactlyOne 2)
-- Out:
-- <interactive>:1:1: error:
--     * Could not deduce (Functor ExactlyOne) arising from a use of `fmap'
--       from the context: Num b bound by the inferred type of it :: Num b => ExactlyOne b at <interactive>:1:1-24
--     * In the expression: fmap (+ 1) (ExactlyOne 2)
--       In an equation for `it': it = fmap (+ 1) (ExactlyOne 2)

-- %%
(+1) <$> ExactlyOne 2
-- Out:
-- <interactive>:1:1: error:
--     * Could not deduce (Functor ExactlyOne) arising from a use of `<$>'
--       from the context: Num b bound by the inferred type of it :: Num b => ExactlyOne b at <interactive>:1:1-21
--     * In the expression: (+ 1) <$> ExactlyOne 2
--       In an equation for `it': it = (+ 1) <$> ExactlyOne 2

-- %% [markdown]
-- ## Exercises
--
-- ### 1. Write a Functor Instance for List
--
-- The `List` data type you looked at the in the List exercises is a Functor,
--
-- Implement `fmap` for `List`.
--
-- #### Exercise

-- %%
instance Functor List where
  fmap :: (a -> b) -> List a -> List b
  fmap = _implementFmapForList
-- Out:
-- <interactive>:2:11: error:
--     * Illegal type signature in instance declaration: fmap :: (a -> b) -> List a -> List b
--       (Use InstanceSigs to allow this)
--     * In the instance declaration for `Functor List'

-- %% [markdown]
-- #### Tests

-- %%
-- >>> fmap (+1) Nil
-- []
fmap (+1) Nil
-- Out:
-- <interactive>:1:1: error:
--     * Could not deduce (Functor List) arising from a use of `fmap'
--       from the context: Num b bound by the inferred type of it :: Num b => List b at <interactive>:1:1-13
--     * In the expression: fmap (+ 1) Nil
--       In an equation for `it': it = fmap (+ 1) Nil

-- %%
-- >>> (+1) <$> (1 :. 2 :. 3 :. Nil)
-- [2,3,4]
(+1) <$> (1 :. 2 :. 3 :. Nil)
-- Out:
-- <interactive>:1:1: error:
--     * Could not deduce (Functor List) arising from a use of `<$>'
--       from the context: Num b bound by the inferred type of it :: Num b => List b at <interactive>:1:1-29
--     * In the expression: (+ 1) <$> (1 :. 2 :. 3 :. Nil)
--       In an equation for `it': it = (+ 1) <$> (1 :. 2 :. 3 :. Nil)

-- %% [markdown]
-- ### 2. Write a Functor Instance for `Optional`
--
-- The `Optional` data type you examined in the `Course.Optional` exercises is also an example of a `Functor`.
--
-- Implement `fmap` for `Optional`.
--
-- #### Exercise

-- %%
instance Functor Optional where
  fmap :: (a -> b) -> Optional a -> Optional b
  fmap = _implementMe
-- Out:
-- <interactive>:2:11: error:
--     * Illegal type signature in instance declaration: fmap :: (a -> b) -> Optional a -> Optional b
--       (Use InstanceSigs to allow this)
--     * In the instance declaration for `Functor Optional'

-- %% [markdown]
-- ### Expected outputs

-- %%
-- >>> (+1) <$> Empty
-- Empty
(+1) <$> Empty
-- Out:
-- <interactive>:1:1: error:
--     * Could not deduce (Functor Optional) arising from a use of `<$>'
--       from the context: Num b bound by the inferred type of it :: Num b => Optional b at <interactive>:1:1-14
--     * In the expression: (+ 1) <$> Empty
--       In an equation for `it': it = (+ 1) <$> Empty

-- %%
-- >>> (+1) <$> Full 2
-- Empty
(+1) <$> Full 2
-- Out:
-- <interactive>:1:1: error:
--     * Could not deduce (Functor Optional) arising from a use of `<$>'
--       from the context: Num b bound by the inferred type of it :: Num b => Optional b at <interactive>:1:1-15
--     * In the expression: (+ 1) <$> Full 2
--       In an equation for `it': it = (+ 1) <$> Full 2

-- %% [markdown]
-- ### 3. Implement the "Anonymous map"
--
-- The "Anonymous Map" operator `<$` Maps a constant value on a `Functor`.
--
-- The `<` can be thought of as indicating the term that takes precedent; the `<` points to the value on the
-- left which overrides any values associated with the `Functor`.
--
-- #### Exercise

-- %%
(<$) :: (Functor f) => a -> f b -> f a
(<$) x = _implementMe
-- Out:
-- <interactive>:2:10: error:
--     * Found hole: _implementMe :: f b -> f a
--       Where: `b' is a rigid type variable bound by
--                the type signature for:
--                  (<$) :: forall (f :: * -> *) a b. Functor f => a -> f b -> f a
--                at <interactive>:1:1-38
--              `f' is a rigid type variable bound by
--                the type signature for:
--                  (<$) :: forall (f :: * -> *) a b. Functor f => a -> f b -> f a
--                at <interactive>:1:1-38
--              `a' is a rigid type variable bound by
--                the type signature for:
--                  (<$) :: forall (f :: * -> *) a b. Functor f => a -> f b -> f a
--                at <interactive>:1:1-38
--       Or perhaps `_implementMe' is mis-spelled, or not in scope
--     * In the expression: _implementMe
--       In an equation for `<$': (<$) x = _implementMe
--     * Relevant bindings include
--         x :: a (bound at <interactive>:2:6)
--         (<$) :: a -> f b -> f a (bound at <interactive>:2:1)

-- %% [markdown]
-- #### Expected Outputs

-- %%
-- >>> 7 <$ (1 :. 2 :. 3 :. Nil)
-- [7,7,7]
7 <$ (1 :. 2 :. 3 :. Nil)
-- Out:
-- <interactive>:1:1: error:
--     * Could not deduce (Functor List) arising from a use of `<$'
--       from the context: Num a bound by the inferred type of it :: Num a => List a at <interactive>:1:1-25
--     * In the expression: 7 <$ (1 :. 2 :. 3 :. Nil)
--       In an equation for `it': it = 7 <$ (1 :. 2 :. 3 :. Nil)

-- %% [markdown]
-- ### 4. Unit Anonymous Map
--
-- An anonymous map producing a unit (`()`) value.
--
-- #### Exercise

-- %%
void :: (Functor f) => f b -> f ()
void = _implementMe
-- Out:
-- <interactive>:2:8: error:
--     * Found hole: _implementMe :: f b -> f ()
--       Where: `b' is a rigid type variable bound by
--                the type signature for:
--                  void :: forall (f :: * -> *) b. Functor f => f b -> f ()
--                at <interactive>:1:1-34
--              `f' is a rigid type variable bound by
--                the type signature for:
--                  void :: forall (f :: * -> *) b. Functor f => f b -> f ()
--                at <interactive>:1:1-34
--       Or perhaps `_implementMe' is mis-spelled, or not in scope
--     * In the expression: _implementMe
--       In an equation for `void': void = _implementMe
--     * Relevant bindings include void :: f b -> f () (bound at <interactive>:2:1)

-- %% [markdown]
-- #### Example outputs

-- %%
-- >>> void (1 :. 2 :. 3 :. Nil)
-- [(),(),()]
void (1 :. 2 :. 3 :. Nil)
-- Out:
-- <interactive>:1:1: error:
--     * No instance for (Functor List) arising from a use of `void'
--     * In the expression: void (1 :. 2 :. 3 :. Nil)
--       In an equation for `it': it = void (1 :. 2 :. 3 :. Nil)

-- %%
-- >>> void (Full 7)
-- Full ()
void (Full 7)
-- Out:
-- <interactive>:1:1: error:
--     * No instance for (Functor Optional) arising from a use of `void'
--     * In the expression: void (Full 7)
--       In an equation for `it': it = void (Full 7)

-- %%
-- >>> void Empty
-- Empty
void Empty
-- Out:
-- <interactive>:1:1: error:
--     * No instance for (Functor Optional) arising from a use of `void'
--     * In the expression: void Empty
--       In an equation for `it': it = void Empty

-- %% [markdown]
-- ### 5. (Advanced) Write a `Functor` Instance for the "Reader"
--
-- Observe the "kind" of `->` that you are hopefully by now accustomed to seeing in type signatures like `foo :: a -> b -> c`:

-- %%
:k (->)
-- Out:
-- (->) :: TYPE q -> TYPE r -> *

-- %% [markdown]
-- If you give it a type, **and then** another, you would arrive at a concrete type:

-- %%
:k (->) Int Char
-- Out:
-- (->) Int Char :: *

-- %% [markdown]
-- Which is the same as:

-- %%
:k Int -> Char
-- Out:
-- Int -> Char :: *

-- %% [markdown]
-- Now consider the "kind" if we were to just give it one type:

-- %%
:k (->) Int
-- Out:
-- (->) Int :: * -> *

-- %% [markdown]
-- `* -> *` means it is waiting for you to specify another concrete type, and then you will (finally) get another concrete type.

-- %% [markdown]
-- `(->) Int` is what we would call an "Int Reader", it "reads" in a value of type `Int` to produce another value, and in fact `(->) Int` has the same "form" or "kind" as other things that hopefully by now you are comfortable using, like:

-- %%
:k ExactlyOne
-- Out:
-- ExactlyOne :: * -> *

-- %%
:k ExactlyOne Int
-- Out:
-- ExactlyOne Int :: *

-- %%
:k Optional
-- Out:
-- Optional :: * -> *

-- %%
:k List
-- Out:
-- List :: * -> *

-- %% [markdown]
-- To demonstrate that `(->) Int` is "almost" as familiar to you, observe the following type alias:

-- %%
type IntReader = (->) Int

-- %%
:k IntReader
-- Out:
-- IntReader :: * -> *

-- %%
:k IntReader Char
-- Out:
-- IntReader Char :: *

-- %%
isEven :: IntReader Bool
isEven x = if (x `mod` 2) == 0 then True else False

-- %% [markdown]
-- Which is *the same* as:

-- %%
isEven1 :: Int -> Bool
isEven1 x = if (x `mod` 2) == 0 then True else False

-- %% [markdown]
-- You can play around with these here:

-- %%
isEven 56
-- Out:
-- True

-- %% [markdown]
-- #### Exercise
--
-- There is nothing special about `Int`, so the exercise is to implement `fmap` for `(->) r`:

-- %%
type Reader = (->)

instance Functor (Reader r) where
  fmap :: (a -> b) -> (Reader r) a -> (Reader r) b
  fmap = (.)

-- %% [markdown]
-- #### Example outputs

-- %%
-- >>> fmap (+1) (*2) 8
-- 17
fmap (+1) (*2) 8
-- Out:
-- 17

-- %%
((+1) <$> (*2)) 8
-- Out:
-- 17

-- %%
-- >>> void (*2) 8
void (*2) 8
-- Out:
-- ()

-- %% [markdown]
-- #### Hints
--
-- Here are some alternative, equivalent, ways to rearrange the type of `fmap` in the exercise,
-- one or more of which might be more natural for the particular way you think:
--
-- Note the use of [*equational reasoning*](http://www.haskellforall.com/2013/12/equational-reasoning.html).
--
-- ``` haskell
-- fmap :: (a -> b) -> Reader r a -> Reader r b
--
-- -- Reader r a ~ (Reader r) a
-- fmap :: (a -> b) -> (Reader r) a -> (Reader r) b
--
--
-- -- Reader r ~ (->) r
-- fmap :: (a -> b) -> ((->) r) a -> ((->) r) b
--
--
-- -- ((->) r) a ~ (->) r a
-- fmap :: (a -> b) -> ((->) r a) -> ((->) r b)
--
--
-- -- (->) r a ~ r -> a
-- fmap :: (a -> b) -> (r -> a) -> (r -> b)
--
--
-- -- a -> (b -> c) ~ a -> b -> c
--
-- -- Note that if you wish to apply the above,
--
-- -- `(b -> c)` MUST be the last in the term,
--
-- -- That is because this rule comes from the Right Associativity of the (->) operator
-- fmap :: (a -> b) -> (r -> a) -> r -> b
-- ```
--
-- It wasn't exactly the quickest way to get form the top to the bottom, but it more about providing more variety.
--
-- Everybody seems to have a different expression of the same type that "clicks" when it comes to understanding this particular Functor.
